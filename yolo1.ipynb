# %% [markdown]
# ## YOLO model on Image dataset for Self Driving Cars

# %% [markdown]
# ### Group Members
# 1. Shubham Deshmukh
# 2. Anirudha Thorat
# 3. Priyanshu Tripathi
# 4. Gaurav Gupta

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# %cd yolov5/
# Out:
# C:\Users\Shubham\Desktop\yolo\yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !/content/yolov5/weights/download_weights.sh
# Out:
# The system cannot find the path specified.

# %%
# %cd ..
# Out:
# C:\Users\Shubham\Desktop\yolo\yolov5

# %%
# !python train.py --img 480 --batch 8 --epochs 5 --data coco128.yaml --weights yolov5m.pt --nosave --cache
# Out:
# train: weights=yolov5m.pt, cfg=, data=coco128.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=5, batch_size=8, imgsz=480, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# From https://github.com/ultralytics/yolov5
#    15b7565..10c025d  master          -> origin/master
#  * [new branch]      exp12           -> origin/exp12
#  * [new branch]      exp13           -> origin/exp13
#    989d244..2e3c515  ultralytics/HUB -> origin/ultralytics/HUB
#    3d1b364..3d89282  update/threaded -> origin/update/threaded
#  * [new tag]         v7.0            -> v7.0
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs/train
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 18148), started 0:04:05 ago. (Use '!kill 18148' to kill it.)
#       <iframe id="tensorboard-frame-17779f90abe5cddc" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-17779f90abe5cddc");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !python val.py --weights runs\train\exp\weights\last.pt --data coco128.yaml --img 480
# Out:
# val: data=C:\Users\Shubham\Desktop\yolo\yolov5\data\coco128.yaml, weights=['runs\\train\\exp\\weights\\last.pt'], batch_size=32, imgsz=480, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5  v6.2-192-g16f87bb Python-3.10.4 torch-1.12.1+cpu CPU
#
# Fusing layers...
# Model summary: 212 layers, 20869098 parameters, 0 gradients, 47.9 GFLOPs
#
# val: Scanning 'C:\Users\Shubham\Desktop\yolo\yolov5\train_data\labels\val' images and labels...:   0%|          | 0/14 [00:00<?, ?it/s]
# val: Scanning 'C:\Users\Shubham\Desktop\yolo\yolov5\train_data\labels\val' images and labels...1 found, 0 missing, 0 empty, 0 corrupt:   7%|7         | 1/14 [00:15<03:16, 15.14s/it]
# ...

# %% [markdown]
# ### input image to yolo

# %%
import matplotlib.pyplot as plt
img = cv2.imread("yolov5/runs/val/exp7/val_batch0_pred.jpg")

plt.figure(figsize=(15, 10))
plt.imshow(img)

# %% [markdown]
# ### Predicted output with Labels

# %%
import matplotlib.pyplot as plt
img = cv2.imread("yolov5/runs/val/exp7/val_batch0_labels.jpg")
#plt.imshow("label",img)

plt.figure(figsize=(15, 10))
plt.imshow(img)
